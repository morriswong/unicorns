# %%
import json
import requests
import urllib3
import certifi
import pandas as pd
import numpy as np
from urllib.parse import urlencode
from bs4 import BeautifulSoup
http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',
    ca_certs=certifi.where())
url = 'https://www.cbinsights.com/research-unicorn-companies'

# %%
html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")
div = soup.find_all("div", {"class" : "contents"})
table = soup.find_all("td")

# %%
i = 0
all_entries = []
for elem in table:
    entries = elem.text.split('\n')
    all_entries.append(elem.text)

# %%
head = [] 
df = {}
header_dict = {}
for item in div:
    headers = item.find_all('th')
    rows = item.find_all('td')
    
    for header in headers:
        head.append(header.text)
        header_dict[i] = header.text
        df[header.text] = []

# %%
i = 0
for entry in all_entries:
    if i < 6:
        df[head[i]].append(entry)
        i += 1
    else:
        i = 0
        df[head[i]].append(entry)
        i += 1

# %%
table = pd.DataFrame(df)

# %%
table
# Out:
#                                             Company         Country  \
# 0                                              Uber   United States
# 1                                Didi Chuxing\n\t             China
# 2                                            Xiaomi           China
# 3    China Internet Plus Holding (Meituan Dianping)           China
# 4                                            Airbnb   United States
# 5                                            SpaceX   United States
# 6                        Palantir\n\t  Technologies   United States
# 7                                            WeWork   United States
# 8                                            Lu.com           China
# 9                                         Pinterest   United States
# 10                                         Flipkart           India
# 11                                             Lyft   United States
# 12                                          Toutiao           China
# 13                                          Dropbox   United States
# 14                                            Infor   United States
# 15                             DJI\n\t  Innovations           China
# 16                                           Stripe   United States
# 17                                          Spotify          Sweden
# 18                                         Snapdeal           India
# 19                                    Global Switch  United Kingdom
# 20                                         GrabTaxi       Singapore
# 21                                          Lianjia           China
# 22       One97\n\t  Communications (operates Paytm)           India
# 23                                       Vice Media   United States
# 24                       Intarcia\n\t  Therapeutics   United States
# 25                                           Ele.me           China
# 26                          Slack\n\t  Technologies   United States
# 27                                   Outcome Health   United States
# 28                        United Imaging Healthcare           China
# 29                                          Coupang     South Korea
# ..                                              ...             ...
# 190                                     Xiaohongshu           China
# 191                                        iCarbonX           China
# 192        Symphony Communication Services Holdings   United States
# 193                                 Age of Learning   United States
# 194                                       Glassdoor   United States
# 195                                           Quikr           India
# 196                                      SMS Assist   United States
# 197                                  benevolent.ai   United Kingdom
# 198                                   Mofang Gongyu           China
# 199                                 UBTECH Robotics           China
# 200                        Adaptive Biotechnologies   United States
# 201                                         HuJiang           China
# 202                                           Guazi           China
# 203                                  Rubicon Global   United States
# 204                                           Zhihu           China
# 205                                     51Xinyongka           China
# 206                                       YH Global           China
# 207                                      Eventbrite   United States
# 208                                         Cylance   United States
# 209                                         Zscaler   United States
# 210                                             Ofo           China
# 211                                      Rocket Lab   United States
# 212                                      Improbable  United Kingdom
# 213                             Zoom Communications   United States
# 214                              Wheels Up Partners   United States
# 215                              Tongdun Technology           China
# 216                                         Supreme   United States
# 217                                        Particle   United States
# 218                                 Face++ (Megvii)           China
# 219                                        XiaoZhu            China
#
#     Date Joined                      Industry  \
# 0     8/23/2013                     On-Demand
# 1    12/31/2014                     On-Demand
# 2    12/21/2011                      Hardware
# 3    12/22/2015         eCommerce/Marketplace
# 4     7/26/2011         eCommerce/Marketplace
# 5     12/1/2012          Other Transportation
# 6      5/5/2011                      Big Data
# 7      2/3/2014                    Facilities
# 8    12/26/2014                       Fintech
# 9     5/19/2012                        Social
# 10     8/6/2012         eCommerce/Marketplace
# 11    3/12/2015                     On-Demand
# 12     4/7/2017                 Digital Media
# 13    10/5/2011  Internet Software & Services
# 14   11/16/2016  Internet Software & Services
# 15     5/6/2015                      Hardware
# 16    1/23/2014                       Fintech
# 17    6/17/2011  Internet Software & Services
# 18    5/21/2014         eCommerce/Marketplace
# 19   12/22/2016  Computer Hardware & Services
# 20    12/4/2014                     On-Demand
# 21     4/8/2016         eCommerce/Marketplace
# 22    5/12/2015                       Fintech
# 23    8/17/2013                         Media
# 24     4/1/2014                    Healthcare
# 25    8/28/2015                     On-Demand
# 26   10/31/2014  Internet Software & Services
# 27    5/31/2017                    Healthcare
# 28    9/14/2017                    Healthcare
# 29    5/28/2014         eCommerce/Marketplace
# ..          ...                           ...
# 190   3/31/2016         eCommerce/Marketplace
# 191   4/12/2016                    Healthcare
# 192   5/16/2017                       Fintech
# 193    5/3/2016                        Edtech
# 194    6/3/2016  Internet Software & Services
# 195    4/7/2015         eCommerce/Marketplace
# 196   6/13/2016  Internet Software & Services
# 197    6/2/2015                    Healthcare
# 198   4/13/2016                    Facilities
# 199   7/26/2016                      Robotics
# 200    1/8/2015                    Healthcare
# 201  10/29/2015                        Edtech
# 202   3/12/2016         eCommerce/Marketplace
# 203   8/25/2017                     Cleantech
# 204   1/12/2017  Internet Software & Services
# 205   9/21/2016                       Fintech
# 206   9/21/2017        Supplychain/ logistics
# 207   3/13/2014         eCommerce/Marketplace
# 208    6/8/2016                 Cybersecurity
# 209    8/3/2015                 Cybersecurity
# 210    3/1/2017                     On Demand
# 211   3/21/2017                     SpaceTech
# 212   5/12/2017                         AR/VR
# 213   1/17/2017  Internet Software & Services
# 214   10/9/2017                    TravelTech
# 215  10/10/2017                 Cybersecurity
# 216   10/9/2017        Clothing & Accessories
# 217  10/17/2017                 Digital Media
# 218  10/31/2017       AI / Facial Recognition
# 219   11/1/2017         eCommerce/Marketplace
#
#                                       Select Investors Valuation ($B)
# 0    Lowercase Capital,\n\t  Benchmark Capital, Goo...            $68
# 1    Matrix Partners, Tiger\n\t  Global Management,...            $50
# 2    Digital Sky Technologies,\n\t  QiMing Venture ...            $46
# 3      DST Global, Trustbridge Partners, Capital Today            $30
# 4    General Catalyst Partners,\n\t  Andreessen Hor...          $29.3
# 5    Founders Fund, Draper\n\t  Fisher Jurvetson, R...          $21.5
# 6           RRE Ventures, Founders\n\t  Fund, In-Q-Tel            $20
# 7    T. Rowe Price, Benchmark\n\t  Capital, SoftBan...            $20
# 8     Ping An Insurance CDH Investments, Bank of China          $18.5
# 9    Andreessen Horowitz, Bessemer Venture Partners...          $12.3
# 10      Accel Partners, SoftBank Group, Iconiq Capital          $11.6
# 11         Founders Fund, Mayfield\n\t  Fund, capitalG          $11.5
# 12   Sequoia Capital China, SIG Asia Investments, S...            $11
# 13   Accel Partners, Greylock\n\t  Partners, Index ...            $10
# 14                   Blackstone Group, Koch Industries            $10
# 15                Accel Partners, Sequoia\n\t  Capital            $10
# 16   Khosla Ventures, Lowercase\n\t  Capital, capitalG           $9.2
# 17   Horizons Ventures, Norwest\n\t  Venture Partne...          $8.53
# 18              SoftBankGroup,Blackrock, Alibaba Group             $7
# 19   Aviation Industry Corporation of China, Essenc...          $6.02
# 20   GGV Capital, Vertex Venture\n\t  Holdings, Sof...             $6
# 21                    Tencent, Baidu, Huasheng Capital           $5.8
# 22   Intel Capital, Sapphire\n\t  Ventures, Alibaba...           $5.7
# 23   Technology Crossover Ventures, A&E; Television...           $5.7
# 24   New Enterprise Associates,\n\t  New Leaf Ventu...           $5.5
# 25   Sequoia Capital China, Alibaba Group, Horizons...           $5.5
# 26   Google Ventures, Institutional Venture Partner...           $5.1
# 27   Goldman Sachs, capitalG, Pritzker Group Ventur...             $5
# 28   China Life Insurance, China Development Bank C...             $5
# 29   Sequoia Capital, Founder\n\t  Collective, Well...             $5
# ..                                                 ...            ...
# 190                     GGV Capital, ZhenFund, Tencent             $1
# 191                                   Tencent, Vcanbio             $1
# 192                 BNP Paribas, Goldman Sachs, Google             $1
# 193                                     Iconiq Capital             $1
# 194  T. Rowe Price, Battery Ventures, Tiger Global ...             $1
# 195   Brand Capital, Tiger Global Management, Kinnevik             $1
# 196  Goldman Sachs, Insights Venture Partners, Prit...             $1
# 197                     Woodford Investment Management             $1
# 198  Warburg Pincus, Aviation Industry Corporation ...             $1
# 199  CDH Investments, Goldstone Investments, Qiming...             $1
# 200                  Illumina, Celgene, Casdin Capital             $1
# 201     China Minsheng Investment, Baidu, Wanxin Media             $1
# 202                  Sequoia Capital China, GX Capital             $1
# 203        Goldman Sachs, Leonardo DiCaprio, Promecap              $1
# 204  Tencent Holdings, Sinovation Ventures, Qiming ...             $1
# 205        GGV Capital, JD.com, Meridian Capital China             $1
# 206                       Co-Energy Finance, Grandland             $1
# 207  Sequoia Capital, Tiger Global Management, SV A...             $1
# 208       Khosla Ventures, Fairhaven Capital, In-Q-Tel             $1
# 209  capitalG, EMC Ventures, Lightspeed Venture Par...             $1
# 210  GSR Ventures, Matrix Partners China, Didi Chuxing             $1
# 211  Lockheed Martin, Khosla Ventures, Bessemer Ven...             $1
# 212  Andreessen Horowitz, SoftBank Group, Temasek H...             $1
# 213  Sequoia Capital, Qualcomm Ventures, Emergence ...             $1
# 214  New Enterprise Associates, Kohlberg Kravis Rob...             $1
# 215  Advantech Capital, Temasek Holdings Ltd., Tian...             $1
# 216                                  The Carlyle Group             $1
# 217                                  Phoenix New Media             $1
# 218  Ant Financial Services Group, Russia-China Inv...             $1
# 219   Morningside Ventures, Capital Today, JOY Capital             $1
#
# [220 rows x 6 columns]

# %%
api_key = open('./api_key').read()

# %%
query = 'Taylor Swift'
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
params = {
    'query': query,
    'limit': 10,
    'indent': True,
    'key': api_key,
}
encoded_args = urlencode(params)
url = service_url + '?' + encoded_args
print (url)
response = http.request('GET', url)
response = json.loads(response.data.decode('utf-8'))
for element in response['itemListElement']:
    print (element['result']['name'] + ' (' + str(element['resultScore']) + ')')
# Out:
# https://kgsearch.googleapis.com/v1/entities:search?query=Taylor+Swift&limit=10&indent=True&key=AIzaSyAfYfYgLoWtoA6jJZLPxbJorC7sm_H5Cjc
# Taylor Swift (916.963623)
# Taylor Swift (515.92157)
# Red (426.328613)
# 2009 MTV Video Music Awards (363.19046)
# Fearless (347.332336)
# Reputation (320.936066)
# 1989 (317.182495)
# Speak Now (201.631317)
# Sounds of the Season: The Taylor Swift Holiday Collection (175.052429)
# Taylor Swift (147.354919)

# %%
# Out:
# {'@context': {'@vocab': 'http://schema.org/',
#   'EntitySearchResult': 'goog:EntitySearchResult',
#   'detailedDescription': 'goog:detailedDescription',
#   'goog': 'http://schema.googleapis.com/',
#   'kg': 'http://g.co/kg',
#   'resultScore': 'goog:resultScore'},
#  '@type': 'ItemList',
#  'itemListElement': [{'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/0dl567',
#     '@type': ['Thing', 'Person'],
#     'description': 'American singer-songwriter',
#     'detailedDescription': {'articleBody': 'Taylor Alison Swift is an American singer-songwriter. One of the leading contemporary recording artists, she is known for narrative songs about her personal life, which have received widespread media coverage.\n',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Taylor_Swift'},
#     'image': {'contentUrl': 'http://t0.gstatic.com/images?q=tbn:ANd9GcST848UJ0u31E6aoQfb2nnKZFyad7rwNF0ZLOCACGpu4jnboEzV',
#      'url': 'https://en.wikipedia.org/wiki/Begin_Again_(Taylor_Swift_song)'},
#     'name': 'Taylor Swift',
#     'url': 'http://taylorswift.com/'},
#    'resultScore': 916.963623},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/03g7rsz',
#     '@type': ['MusicAlbum', 'Thing'],
#     'description': 'Studio album by Taylor Swift',
#     'detailedDescription': {'articleBody': "Taylor Swift is the debut studio album by American singer-songwriter Taylor Swift, released on October 24, 2006, by Big Machine Records. Swift was 16 years old at the time of the album's release and wrote its songs during her freshman year of high school. Swift has writing credits on all of the album's songs, including those co-written with Liz Rose. Swift experimented with several producers, ultimately choosing Nathan Chapman, who had produced her demo album. ",
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Taylor_Swift_(album)'},
#     'name': 'Taylor Swift'},
#    'resultScore': 515.92157},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/0l8mh7y',
#     '@type': ['MusicAlbum', 'Thing'],
#     'description': 'Studio album by Taylor Swift',
#     'detailedDescription': {'articleBody': 'Red is the fourth studio album by American singer-songwriter Taylor Swift. It was released on October 22, 2012, by Big Machine Records, as the follow-up to her third studio album, Speak Now. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Red_(Taylor_Swift_album)'},
#     'image': {'contentUrl': 'http://t0.gstatic.com/images?q=tbn:ANd9GcQBFEwFYnEDjgLRwYNyNnqqMWxG9fS7Fc4Yn6WyxvkZ6MnpPCfv',
#      'url': 'https://commons.wikimedia.org/wiki/File:Taylor_Swift_RED_Tour_(8642419792).jpg'},
#     'name': 'Red'},
#    'resultScore': 426.328613},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/0z688m1',
#     '@type': ['Thing', 'Event'],
#     'description': 'Award ceremony',
#     'name': '2009 MTV Video Music Awards'},
#    'resultScore': 363.19046},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/04glrxj',
#     '@type': ['MusicAlbum', 'Thing'],
#     'description': 'Studio album by Taylor Swift',
#     'detailedDescription': {'articleBody': 'Fearless is the second studio album by the American singer-songwriter Taylor Swift. The album was released on November 11, 2008, by Big Machine Records. As with her first album, Taylor Swift, Swift wrote or co-wrote all thirteen tracks on Fearless. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Fearless_(Taylor_Swift_album)'},
#     'image': {'contentUrl': 'http://t2.gstatic.com/images?q=tbn:ANd9GcTLjFQuuo4Lx364_sdPlqcRUnLLSnRpfGvD4-2a5J-bnrIZVvlj',
#      'url': 'https://commons.wikimedia.org/wiki/File:Taylor_Swift_-_Fearless_Tour_-_Los_Angeles_05.jpg'},
#     'name': 'Fearless'},
#    'resultScore': 347.332336},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/g/11f06kgm76',
#     '@type': ['Thing', 'MusicAlbum'],
#     'description': 'Studio album by Taylor Swift',
#     'name': 'Reputation'},
#    'resultScore': 320.936066},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/011lmk0n',
#     '@type': ['MusicAlbum', 'Thing'],
#     'description': 'Studio album by Taylor Swift',
#     'detailedDescription': {'articleBody': '1989 is the fifth studio album by American singer-songwriter Taylor Swift released on October 27, 2014, through Big Machine Records. Swift began composing the album following release of previous studio effort, Red. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/1989_(Taylor_Swift_album)'},
#     'image': {'contentUrl': 'http://t1.gstatic.com/images?q=tbn:ANd9GcS6iqOwcmtENxZtJdWO2l_Dma-iW-LknVzw6GCas4Eu37uZWF9u',
#      'url': 'https://commons.wikimedia.org/wiki/File:1989_album_logo.png'},
#     'name': '1989'},
#    'resultScore': 317.182495},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/0cmdv8y',
#     '@type': ['MusicAlbum', 'Thing'],
#     'description': 'Studio album by Taylor Swift',
#     'detailedDescription': {'articleBody': 'Speak Now is the third studio album by American singer-songwriter Taylor Swift. It was released on October 25, 2010, by Big Machine Records. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Speak_Now'},
#     'image': {'contentUrl': 'http://t2.gstatic.com/images?q=tbn:ANd9GcRgFyM0pMKbSNsy06Hh3Xl3v9UoAC8B_5pIcgre69X5vXUlKoaN',
#      'url': 'https://commons.wikimedia.org/wiki/File:Taylor_Swift_Speak_Now_Tour_(6966915023).jpg'},
#     'name': 'Speak Now'},
#    'resultScore': 201.631317},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/03cl661',
#     '@type': ['MusicAlbum', 'Thing'],
#     'description': 'Album by Taylor Swift',
#     'detailedDescription': {'articleBody': 'The Taylor Swift Holiday Collection, originally titled Sounds of the Season: The Taylor Swift Holiday Collection, is a Christmas EP by American singer Taylor Swift. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/The_Taylor_Swift_Holiday_Collection'},
#     'name': 'Sounds of the Season: The Taylor Swift Holiday Collection'},
#    'resultScore': 175.052429},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/g/11f_j9c6_v',
#     '@type': ['Thing', 'Event'],
#     'description': 'Event',
#     'name': 'Taylor Swift'},
#    'resultScore': 147.354919}]}
